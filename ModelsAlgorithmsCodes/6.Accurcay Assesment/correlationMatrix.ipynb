# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#import pymc3 as pm

from matplotlib import animation, rc
# %matplotlib inline

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('Correlation2015.csv')

# %%
df.columns
# Out:
# Index(['4', 'X', 'Y', 'S3 OLCI Chl-a', 'L8 Chl-a Estimates'], dtype='object')

# %%
df.head()
# Out:
#           4        X        Y  S3 OLCI Chl-a  L8 Chl-a Estimates
# 0  7/1/2015  34.6883 -0.13600      25.826229           28.672397
# 1       NaN  34.8431 -0.28705      32.192482           27.782982
# 2       NaN  34.6333 -0.33787      20.771219           11.716781
# 3       NaN  34.1963 -0.32962      27.068468           22.068468
# 4       NaN  34.4450 -0.51776      30.188889           24.798715

# %%
data=df[['X',	'Y', 'S3 OLCI Chl-a', 'L8 Chl-a Estimates']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, linewidth=1.0, cmap='Reds')
plt.title('CORRELATION BETWEEN FACTORS AFFECTING MALARIA AND OCCURANCES')
plt.savefig('Correlation.png',dpi=1000, bbox_inches='tight')
plt.show()

# %%
mask1= df["S3 OLCI Chl-a"] == 2014
data14=df[mask1]

# %%
data.head()
# Out:
#          X        Y  S3 OLCI Chl-a  L8 Chl-a Estimates
# 0  34.6883 -0.13600      25.826229           28.672397
# 1  34.8431 -0.28705      32.192482           27.782982
# 2  34.6333 -0.33787      20.771219           11.716781
# 3  34.1963 -0.32962      27.068468           22.068468
# 4  34.4450 -0.51776      30.188889           24.798715

# %%
test_data = data14[['DHSYEAR','LATNUM',	'LONGNUM',	'AGE', 'RESIDENCE', 'RELIGION',	'BoD',	'CURRWORK',	'WEALTHQUANTILE',	'EDUCLVL',	'MEDIANEWS',	'MEDIARADIO','ANCCARE']]
y_test = test_data[['ANCCARE']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14224/3308746301.py in <module>
# ----> 1 test_data = data14[['DHSYEAR','LATNUM', 'LONGNUM',      'AGE', 'RESIDENCE', 'RELIGION', 'BoD',  'CURRWORK',     'WEALTHQUANTILE',       'EDUCLVL',      'MEDIANEWS',    'MEDIARADIO','ANCCARE']]
#       2 y_test = test_data[['ANCCARE']]
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['DHSYEAR', 'LATNUM', 'LONGNUM', 'AGE', 'RESIDENCE', 'RELIGION', 'BoD',\n       'CURRWORK', 'WEALTHQUANTILE', 'EDUCLVL', 'MEDIANEWS', 'MEDIARADIO',\n       'ANCCARE'],\n      dtype='object')] are in the [columns]"

# %%
mask2= df["DHSYEAR"] <2014
data03_08=df[mask2]

# %%
train_data = data03_08[['DHSYEAR','AGE', 'RESIDENCE', 'RELIGION',	'BoD',	'CURRWORK',	'WEALTHQUANTILE',	'EDUCLVL',	'MEDIANEWS',	'MEDIARADIO','ANCCARE']]
y_train = train_data[['ANCCARE']]

# %%
train_data.head()
# Out:
#       DHSYEAR  AGE  RESIDENCE  ...  MEDIANEWS  MEDIARADIO  ANCCARE
# 1593     2008   25          2  ...          1          11        0
# 1594     2008   39          2  ...         12          12        1
# 1595     2008   40          2  ...          1          12        1
# 1596     2008   24          2  ...          1           1        0
# 1597     2008   45          2  ...          1          12        0
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sss= StandardScaler()

# %%
X_train = sss.fit_transform(train_data[['AGE', 'RESIDENCE', 'RELIGION',	'BoD',	'CURRWORK',	'WEALTHQUANTILE',	'EDUCLVL',	'MEDIANEWS',	'MEDIARADIO']])

# %%
X_train
# Out:
# array([[-0.70195299,  0.69716104,  0.68981722, ..., -0.28337873,
#         -0.48082896,  0.27510881],
#        [ 0.85527871,  0.69716104, -0.49145776, ...,  2.08453991,
#          1.56607531,  0.43036824],
#        [ 0.96650954,  0.69716104, -0.49145776, ..., -0.28337873,
#         -0.48082896,  0.43036824],
#        ...,
#        [-0.81318383, -1.43438881, -1.67273275, ..., -0.28337873,
#          1.37999311,  0.27510881],
#        [ 1.52266372,  0.69716104, -0.49145776, ..., -1.46733806,
#         -0.48082896, -1.27748548],
#        [-0.25702965, -1.43438881,  0.68981722, ...,  2.08453991,
#          1.56607531,  0.43036824]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logit_B1 = LogisticRegression()

# %%
logit_B1.fit(X_train, y_train.values.ravel())
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logit_B1.coef_
# Out:
# array([[-1.43851956,  0.3111608 ,  0.18751715,  1.28588871,  0.72050777,
#          0.31413783,  0.29771944, -0.07114722,  0.06805554]])

# %%
test_data
# Out:
#       DHSYEAR    LATNUM    LONGNUM  ...  MEDIANEWS  MEDIARADIO  ANCCARE
# 0        2014 -1.282723  36.752958  ...          1           0        0
# 1        2014 -1.278781  36.758441  ...          1           0        1
# 2        2014 -1.279646  36.745931  ...          2           0        0
# 3        2014 -1.280380  36.697090  ...          1           0        0
# 4        2014 -1.272064  36.743127  ...          1           0        1
# ...       ...       ...        ...  ...        ...         ...      ...
# 1588     2014  0.577623  34.261595  ...          1           0        0
# 1589     2014  0.560891  34.248927  ...          1           0        1
# 1590     2014  0.500992  34.174886  ...          2           1        0
# 1591     2014  0.456166  34.122642  ...          1           0        1
# 1592     2014  0.494860  34.156075  ...          1           0        0
#
# [1593 rows x 13 columns]

# %%
data_test = sss.fit_transform(test_data[['AGE',	'RESIDENCE',	'RELIGION',	'BoD',	'CURRWORK',	'WEALTHQUANTILE',	'EDUCLVL',	'MEDIANEWS',	'MEDIARADIO']])

# %%
data14_pred= logit_B1.predict(data_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, data14_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64       755
#            1       0.67      0.61      0.64       838
#
#     accuracy                           0.64      1593
#    macro avg       0.64      0.64      0.64      1593
# weighted avg       0.64      0.64      0.64      1593

# %%
df['ANCCARE'].unique()
# Out:
# array([0, 1])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_class = RandomForestClassifier(n_estimators=1000)

# %%
RF_class.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
RF_pred = RF_class.predict(data_test)

# %%
accuracy_score(y_test, RF_pred )
# Out:
# 0.7627118644067796

# %%
print(classification_report(y_test, RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73       755
#            1       0.75      0.83      0.79       838
#
#     accuracy                           0.76      1593
#    macro avg       0.77      0.76      0.76      1593
# weighted avg       0.77      0.76      0.76      1593

# %%
test_data.loc[:, "PRED_ANCCARE_RF"] = RF_pred
test_data.loc[:, "PRED_ANCCARE_LR"] = data14_pred

# %%
test_data
# Out:
#       DHSYEAR    LATNUM    LONGNUM  ...  ANCCARE  PRED_ANCCARE_RF  PRED_ANCCARE_LR
# 0        2014 -1.282723  36.752958  ...        0                1                1
# 1        2014 -1.278781  36.758441  ...        1                0                1
# 2        2014 -1.279646  36.745931  ...        0                0                0
# 3        2014 -1.280380  36.697090  ...        0                0                0
# 4        2014 -1.272064  36.743127  ...        1                1                1
# ...       ...       ...        ...  ...      ...              ...              ...
# 1588     2014  0.577623  34.261595  ...        0                0                0
# 1589     2014  0.560891  34.248927  ...        1                1                0
# 1590     2014  0.500992  34.174886  ...        0                0                0
# 1591     2014  0.456166  34.122642  ...        1                1                0
# 1592     2014  0.494860  34.156075  ...        0                0                0
#
# [1593 rows x 15 columns]

# %%
test_data.to_csv('/content/drive/MyDrive/data/PredictionLogistic.csv', index=False)
